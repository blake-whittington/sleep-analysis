# %% [markdown]
# # Are people a good judge of their own sleep and health?
# ***

# %% [markdown]
# ## Set Up
# ## Imports

# %%
import pandas as pd

# %% [markdown]
# ## Parameters

# %%
_2011_POLLDATASET = '../data_file/raw_data_csv/2011SleepinAmericaPollTechnologyUseandSleepRawDataExcel.csv'

# %% [markdown]
# ## Loading Raw Dataset

# %%
_2011_poll = pd.read_csv(_2011_POLLDATASET)
_2011_poll.shape
# Out:
# (1508, 215)

# %%
_2011_poll.head(10)
# Out:
#   VERSION  caseid  qs1  qs2ov1801  qs2ov1802  qs201  qs202 qs3  qs4  q1  ...  \
# 0   PHONE       3   40        3.0        NaN      3    NaN  NY    2  23  ...
# 1   PHONE       4   23        1.0        2.0      1    2.0  TX    2  11  ...
# 2   PHONE       5   52        1.0        NaN      1    NaN  MD    1   5  ...
# 3   PHONE       6   42        1.0        NaN      1    NaN  WV    1  10  ...
# 4   PHONE       7   47        1.0        NaN      1    NaN  NY    2   2  ...
# 5   PHONE       8   55        1.0        NaN      1    NaN  SC    1   2  ...
# 6   PHONE      10   21        1.0        NaN      1    NaN  GA    1  15  ...
# 7   PHONE      11   61        1.0        NaN      1    NaN  IN    1   7  ...
# 8   PHONE      12   26        1.0        NaN      1    NaN  CA    1   7  ...
# 9   PHONE      13   33        3.0        NaN      3    NaN  TX    2  15  ...
#
#    d5ab   d6  makechld  whathap2  Q5GROUPED  Q6GROUPED  Q5Q7DIF  Q6Q7DIF  \
# ...

# %%
_2011_poll.columns.values
# Out:
# array(['VERSION', 'caseid', 'qs1', 'qs2ov1801', 'qs2ov1802', 'qs201',
#        'qs202', 'qs3', 'qs4', 'q1', 'q1FIX', 'q2', 'q2FIX', 'Q2VALUE',
#        'Q1Q2DIF', 'q1q2diffFIX', 'Q1Q2DIFHRS', 'q1q2diffhrsFIX', 'q3',
#        'Q3VALUE', 'q3FIX', 'q4', 'Q4VALUE', 'q4FIX', 'Q3Q4DIF',
#        'q3q4diffFIX', 'Q3Q4DIFHRS', 'q3q4diffhrsFIX', 'Q3Q4Q1Q2DIFHRS',
#        'Q3Q4Q1Q2POS', 'q5text', 'q5h', 'q5m', 'Q5', 'Q5HRS', 'q5dkrf',
#        'q6text', 'q6h', 'q6m', 'Q6', 'Q6HRS', 'q6dkrf', 'Q6Q5DIF',
#        'Q6Q5DIFHRS', 'Q6Q5POS', 'q7text', 'q7hour', 'q7min', 'q7mer',
#        'q7', 'Q7REV', 'Q1VALUE', 'Q1Q7DIF', 'Q1Q7DIFHRS', 'VAR00012',
#        'Q1TIME', 'PREQ7', 'Q5Q7POS', 'q8text', 'q8', 'q9text', 'q9',
#        'q10text', 'q10', 'q11text', 'q11', 'q12text', 'q13text', 'q12',
#        'q13', 'q14text', 'q14a', 'q14b', 'q14c', 'Q14TOTAL', 'q15text',
#        'q15a', 'q15b', 'q15c', 'q15d', 'q15e', 'q15f', 'q15g', 'q15h',
# ...

# %% [markdown]
# ## Drop Unnecessary Columns

# %%
_2011_poll=_2011_poll.drop(labels=['VERSION','qs2ov1802','qs201','qs202','q1FIX',
                                'q2FIX','Q1Q2DIF','q1q2diffFIX','Q1Q2DIFHRS','q1q2diffhrsFIX',
                                'Q3VALUE','q3FIX','Q4VALUE','q4FIX','Q3Q4DIF',
                                'q3q4diffFIX','Q3Q4DIFHRS','q3q4diffhrsFIX','Q3Q4Q1Q2DIFHRS','Q3Q4Q1Q2POS',
                                'q5text','q5dkrf','q6text','q6dkrf','Q6Q5POS','q7text',
                                'q7mer','Q1Q7DIF','Q1Q7DIFHRS','VAR00012','PREQ7',
                                'Q5Q7POS','q8text','q9text','q10text','q11text',
                                'q12text','q13text','q14text','q15text','EPWORTH',
                                'VAR00013','q17text','Q16Q5DIFHRS','Q16Q6DIFHRS','q31text',
                                'q32text','d302','d303','d304','d305',
                                'd306','d307','d308','d309','d4',
                                'complete','qs1a','qs1b','q7dkrf','q21oc01',
                                'q21oc02','q21oc03','q21oc04','q21oc05','q21oc06',
                                'q21oc07','q21oc08','q21oc09','q21oc10','d3oc01',
                                'd3oc02','d3oc03','d3oc04','d3oc05','d5',
                                'd5aa','d5ab','d6','makechld','whathap2',
                                'Q5GROUPED','Q6GROUPED','Q5Q7DIF','Q6Q7DIF','filter_$',
                                'WEIGHT'], axis=1)

# %%
_2011_poll.columns.values
# Out:
# array(['caseid', 'qs1', 'qs2ov1801', 'qs3', 'qs4', 'q1', 'q2', 'Q2VALUE',
#        'q3', 'q4', 'q5h', 'q5m', 'Q5', 'Q5HRS', 'q6h', 'q6m', 'Q6',
#        'Q6HRS', 'Q6Q5DIF', 'Q6Q5DIFHRS', 'q7hour', 'q7min', 'q7', 'Q7REV',
#        'Q1VALUE', 'Q1TIME', 'q8', 'q9', 'q10', 'q11', 'q12', 'q13',
#        'q14a', 'q14b', 'q14c', 'Q14TOTAL', 'q15a', 'q15b', 'q15c', 'q15d',
#        'q15e', 'q15f', 'q15g', 'q15h', 'q16', 'Q16HRS', 'q17', 'q18a',
#        'q18b', 'q18c', 'q18d', 'q18e', 'q18f', 'q19a', 'q19b', 'q19c',
#        'q19d', 'q19e', 'q19f', 'q19g', 'q19h', 'q20a', 'q20b', 'q20c',
#        'q20d', 'q20e', 'q20f', 'q20g', 'q20h', 'q20i', 'q20j', 'q20k',
#        'q20l', 'q20m', 'q20n', 'q21', 'q22', 'q23a', 'q23b', 'q23c',
#        'q23d', 'q23e', 'q23f', 'q23g', 'q23h', 'q23i', 'q24', 'q25',
#        'q26', 'q27', 'q28a', 'q28b', 'q28c', 'q28d', 'q28e', 'q28f',
#        'q29', 'q30a', 'q30b', 'q30c', 'q30d', 'q30e', 'q31', 'q32',
# ...

# %% [markdown]
# ## Rename Ambiguous Columns

# %%
_2011_poll.rename(columns = {'caseid':'id', 'qs1':'age','qs2ov1801':'employment_status', 'qs3':'state', 'qs4':'gender','q1':'wake_up_weekdays',
                            'q2':'bed_time_weekdays', 'Q2VALUE':'bed_time_wrong','q3':'wake_up_weekends', 'q4':'bed_time_weekends','q5h':'hours_sleep_weekday',
                            'q5m':'mins_sleep_weekday', 'Q5':'total_mins_sleep_weekday','Q5HRS':'total_hours_sleep_weekday', 'q6h':'hours_sleep_weekend','q6m':'mins_sleep_weekend',
                            'Q6':'mins_sleep_weekend', 'Q6HRS':'total_hours_sleep_weekend','Q6Q5DIF':'diff_mins_weekend_weekday', 'Q6Q5DIFHRS':'diff_hours_weekend_weekday','q7hour':'leave_home_hour',
                            'q7min':'leave_home_min', 'q7':'leave_home_am','Q7REV':'leave_home_pm', 'Q1VALUE':'wake_up_wrong','Q1TIME':'wake_up_weekday_time',
                            'q8':'naps_weekday', 'q9':'nap_mins_weekday','q10':'naps_weekend', 'q11':'naps_mins_weekend','q12':'good_rest_often_weekday',
                            'q13':'good_rest_often_weekend', 'q14a':'caffeine_between_05:00-11:59','q14b':'caffeine_between_12:00-16:59', 'q14c':'caffein_between_17:00-04:59','Q14TOTAL':'caffeine_a_day',
                            'q15a':'read_doze_chance', 'q15b':'tv_doze_chance','q15c':'sitting_inactive_doze_chance', 'q15d':'car_traffic_doze_chance','q15e':'passenger_doze_chance',
                            'q15f':'chatting_doze_chance', 'q15g':'after_lunch_no_aclohol__doze_chance','q15h':'lying_down_doze_chance', 'q16':'minimum_sleep_opinion','Q16HRS':'minimum_sleep_hours_opinion',
                            'q17':'schedule_allows_enough_sleep', 'q18a':'sleep_affect_work','q18b':'sleep_affect_school', 'q18c':'sleep_affect_social_activities','q18d':'sleep_affect_home_responsibilities',
                            'q18e':'sleep_affect_mood', 'q18f':'sleep_affect_sexual_relaionship','q19a':'tv_use_hour_before_sleep', 'q19b':'pc_use_hour_before_sleep','q19c':'cellphone_use_hour_before_sleep',
                            'q19d':'telephone_use_hour_before_sleep', 'q19e':'gaming_use_hour_before_sleep','q19f':'music_use_hour_before_sleep', 'q19g':'ebook_use_hour_before_sleep','q19h':'book_use_hour_before_sleep',
                            'q20a':'tv_hour_before_bed_often', 'q20b':'phone_hour_before_bed_often','q20c':'text_hour_before_bed_often', 'q20d':'gaminig_hour_before_bed_often','q20e':'internet_hour_before_bed_often',
                            'q20f':'social_network_hour_before_bed_often', 'q20g':'personal_email_hour_before_bed_often','q20h':'work_email_hour_before_bed_often', 'q20i':'ebook_hour_before_bed_often','q20j':'book_hour_before_bed_often',
                            'q20k':'music_hour_before_bed_often', 'q20l':'watch_video_hour_before_bed_often','q20m':'pc_work_hour_before_bed_often', 'q20n':'pc_school_hour_before_bed_often','q21':'tv_genre_hour_before_sleep',
                            'q22':'where_watch_tv_before_bed', 'q23a':'cellphone_talk_often','q23b':'cellphone_text_often', 'q23c':'cellphone_personal_email_often','q23d':'cellphone_work_email_often',
                            'q23e':'cellphone_internet_often', 'q23f':'cellphone_gaming_often','q23g':'cellphone_music_often', 'q23h':'cellphone_video_often','q23i':'cellphone_alarm_often',
                            'q24':'cellohone_ready_sleep', 'q25':'calls_trying_sleep','q26':'sleep_with_light_often', 'q27':'computer_before_bed_often','q28a':'pc_internet_often',
                            'q28b':'pc_im_often', 'q28c':'pc_email_often','q28d':'pc_video_often', 'q28e':'pc_music_often','q28f':'pc_word_excel_often',
                            'q29':'type_game_most_often', 'q30a':'game_violence_often','q30b':'game_blood_often', 'q30c':'game_sexual_often','q30d':'game_crude_humor_often',
                            'q30e':'game_gambling_often', 'q31':'fall_asleep_weekday_mins','q32':'fall_asleep_weekend_mins', 'q33a':'difficulty_falling_asleep_often','q33e':'snore_often',
                            'q33b':'woke_up_during_night_often', 'q33c':'woke_too_early_often','q33d':'unrefreshed_often', 'q34':'mins_awake_during_night_too_early','q35a':'tv_woke_during_night_too_early',
                            'q35b':'phone_woke_during_night_too_early', 'q35c':'text_woke_during_night_too_early','q35d':'gaming_woke_during_night_too_early', 'q35e':'internet_woke_during_night_too_early','q35f':'social_network_woke_during_night_too_early',
                            'q35g':'personal_email_woke_during_night_too_early', 'q35h':'work_email_woke_during_night_too_early','q35i':'ebook_woke_during_night_too_early', 'q35j':'book_woke_during_night_too_early','q35k':'music_woke_during_night_too_early',
                            'q35l':'video_woke_during_night_too_early', 'q35m':'work_pc_woke_during_night_too_early','q35n':'homework_pc_woke_during_night_too_early', 'q36':'drive_tired_last_month','d1':'marital_status',
                            'd2':'hispanic', 'd301':'race'
                            }, inplace = True)

# %%
_2011_poll.columns.values
# Out:
# array(['id', 'age', 'employment_status', 'state', 'gender',
#        'wake_up_weekdays', 'bed_time_weekdays', 'bed_time_wrong',
#        'wake_up_weekends', 'bed_time_weekends', 'hours_sleep_weekday',
#        'mins_sleep_weekday', 'total_mins_sleep_weekday',
#        'total_hours_sleep_weekday', 'hours_sleep_weekend',
#        'mins_sleep_weekend', 'mins_sleep_weekend',
#        'total_hours_sleep_weekend', 'diff_mins_weekend_weekday',
#        'diff_hours_weekend_weekday', 'leave_home_hour', 'leave_home_min',
#        'leave_home_am', 'leave_home_pm', 'wake_up_wrong',
#        'wake_up_weekday_time', 'naps_weekday', 'nap_mins_weekday',
#        'naps_weekend', 'naps_mins_weekend', 'good_rest_often_weekday',
#        'good_rest_often_weekend', 'caffeine_between_05:00-11:59',
#        'caffeine_between_12:00-16:59', 'caffein_between_17:00-04:59',
#        'caffeine_a_day', 'read_doze_chance', 'tv_doze_chance',
#        'sitting_inactive_doze_chance', 'car_traffic_doze_chance',
# ...

# %%
_2011_poll.head(10)
# Out:
#    id  age  employment_status state  gender  wake_up_weekdays  \
# 0   3   40                3.0    NY       2                23
# 1   4   23                1.0    TX       2                11
# 2   5   52                1.0    MD       1                 5
# 3   6   42                1.0    WV       1                10
# 4   7   47                1.0    NY       2                 2
# 5   8   55                1.0    SC       1                 2
# 6  10   21                1.0    GA       1                15
# 7  11   61                1.0    IN       1                 7
# 8  12   26                1.0    CA       1                 7
# 9  13   33                3.0    TX       2                15
#
#    bed_time_weekdays  bed_time_wrong  wake_up_weekends  bed_time_weekends  \
# 0                  3          1300.0                23                  4
# 1                  4          1400.0                25                 18
# ...

# %% [markdown]
# ## Save Data

# %%
_2011_poll.to_pickle('../data_file/cleaned_data_pickle/2011_poll_df.pickle')

# %%
_2011_poll.to_csv(r'../data_file/cleaned_data_csv/clean_2011_POLLDATASET.csv', index = False)
