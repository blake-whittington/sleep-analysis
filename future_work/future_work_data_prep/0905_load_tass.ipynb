# %% [markdown]
# ## How Does Economic Health Affect People’s Sleep?
# ***

# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %%
TASS = '../data_file/raw_data_csv/Time_Americans_Spend_Sleeping.csv'
tass_df = pd.read_csv(TASS)

# %%
tass_df
# Out:
#      Year  Period  Avg hrs per day sleeping  Standard Error  \
# 0    2003  Annual                      8.57           0.018
# 1    2004  Annual                      8.55           0.026
# 2    2005  Annual                      8.62           0.023
# 3    2006  Annual                      8.63           0.024
# 4    2007  Annual                      8.57           0.024
# ..    ...     ...                       ...             ...
# 940  2013  Annual                      8.83           0.085
# 941  2014  Annual                      8.98           0.086
# 942  2015  Annual                      8.83           0.074
# 943  2016  Annual                      8.92           0.071
# 944  2017  Annual                      8.81           0.091
#
#             Type of Days          Age Group  Activity    Sex
# 0               All days  15 years and over  Sleeping   Both
# 1               All days  15 years and over  Sleeping   Both
# ...

# %%
tass_df.rename(columns={'Avg hrs per day sleeping':'avg_hrs_day_sleeping', 'Type of Days':'type_of_days', 'Age Group':'age_group', 'Activity':'activity', 'Sex':'sex'}, inplace=True)

# %%
tass_df
# Out:
#      Year  Period  avg_hrs_day_sleeping  Standard Error         type_of_days  \
# 0    2003  Annual                  8.57           0.018             All days
# 1    2004  Annual                  8.55           0.026             All days
# 2    2005  Annual                  8.62           0.023             All days
# 3    2006  Annual                  8.63           0.024             All days
# 4    2007  Annual                  8.57           0.024             All days
# ..    ...     ...                   ...             ...                  ...
# 940  2013  Annual                  8.83           0.085  Nonholiday weekdays
# 941  2014  Annual                  8.98           0.086  Nonholiday weekdays
# 942  2015  Annual                  8.83           0.074  Nonholiday weekdays
# 943  2016  Annual                  8.92           0.071  Nonholiday weekdays
# 944  2017  Annual                  8.81           0.091  Nonholiday weekdays
#
#              age_group  activity    sex
# ...

# %%
for cell in tass_df['avg_hrs_day_sleeping']:
    print(cell)
# Out:
# 8.57
# 8.55
# 8.62
# 8.63
# 8.57
# 8.6
# 8.67
# 8.67
# 8.71
# 8.73
# 8.74
# 8.8
# 8.83
# 8.79
# 8.8
# 8.26
# 8.25
# 8.35
# 8.33
# 8.29
# 8.3
# 8.39
# 8.38
# 8.45
# 8.45
# 8.48
# 8.54
# 8.59
# 8.5
# 8.53
# 9.29
# 9.25
# 9.28
# 9.32
# 9.24
# 9.31
# 9.33
# 9.34
# 9.35
# 9.39
# 9.34
# 9.4
# 9.4
# 9.48
# 9.44
# 9.15
# 9.23
# 9.27
# 9.19
# 9.11
# 9.2
# 9.45
# 9.24
# 9.32
# 9.34
# 9.34
# 9.53
# 9.58
# 9.55
# 9.72
# 8.75
# 8.79
# 9.01
# 8.84
# 8.71
# 8.83
# 9.19
# 8.94
# 8.99
# 8.95
# 9.0
# 9.31
# 9.39
# 9.12
# 9.38
# 10.1
# 10.28
# 9.89
# 10.03
# 10.0
# 10.04
# 10.04
# 9.96
# 10.13
# 10.25
# 10.16
# 10.06
# 10.02
# 10.58
# 10.48
# 8.52
# 8.46
# 8.65
# 8.58
# 8.57
# 8.54
# 8.54
# 8.58
# 8.6
# 8.76
# 8.65
# 8.77
# 8.87
# 8.71
# 8.76
# 8.18
# 8.08
# 8.24
# 8.19
# 8.22
# 8.16
# 8.18
# 8.25
# 8.26
# 8.45
# 8.34
# 8.44
# 8.63
# 8.36
# 8.41
# 9.34
# 9.37
# 9.6
# 9.47
# 9.4
# 9.45
# 9.43
# 9.4
# 9.39
# 9.49
# 9.37
# 9.52
# 9.43
# 9.55
# 9.56
# 8.34
# 8.25
# 8.37
# 8.39
# 8.35
# 8.38
# 8.41
# 8.4
# ...

# %%
tass_df.groupby(['sex'])['avg_hrs_day_sleeping'].describe()
# Out:
#        count      mean       std   min    25%   50%    75%    max
# sex
# Both   315.0  8.807841  0.536862  7.85  8.365  8.79  9.185  10.58
# Men    315.0  8.731587  0.571327  7.72  8.275  8.73  9.140  10.65
# Women  315.0  8.881175  0.516828  7.90  8.480  8.85  9.255  10.52

# %%
tass_df.groupby(['sex'])['avg_hrs_day_sleeping'].describe()
# Out:
#        count      mean       std   min    25%   50%    75%    max
# sex
# Both   315.0  8.807841  0.536862  7.85  8.365  8.79  9.185  10.58
# Men    315.0  8.731587  0.571327  7.72  8.275  8.73  9.140  10.65
# Women  315.0  8.881175  0.516828  7.90  8.480  8.85  9.255  10.52

# %%
tass_df.to_pickle('../data_file/cleaned_data_pickle/tass_df.pickle')

# %%
tass_df.to_csv('../data_file/cleaned_data_csv/tass_df.csv')
