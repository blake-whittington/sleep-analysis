# %% [markdown]
# # How Not To Put A Nation To Sleep
# ## Blake Whittington and Gabriele Spiridaviciute
# ***
# ## Are People a Good Judge of Their Own Sleep and Health?
#
# ### Cluster Desirability Analysis
# Now that we have a a cleaned dataset with clusters associated with every surveyor, we can start to look at the desirability of each cluster. In this notebook the desirability will be based off frequency of each cluster and the clusters that are homogenous for health and sleep ratings

# %%
import pandas as pd
import numpy as np
mod = '../data_file/cleaned_data_pickle/2013_df_MOD.pickle'
cluster_df = pd.read_pickle(mod)

# %%
cluster_df.head(60)
# Out:
#     id  age  employment_status  gender state  bed_time_weekdays  \
# 0    1   39                  3    Male    CO                 14
# 1    2   57                  1  Female    AL                 10
# 2    3   51                  1    Male    NV                 14
# 3    3   38                  1    Male    FL                 15
# 4    4   60                  1    Male    CT                 18
# 5    5   39                  1  Female    MA                 18
# 6    6   36                  2  Female    LA                 18
# 7    7   44                  3    Male    NY                 10
# 8    7   34                  1  Female    WA                 12
# 9    8   38                  1    Male    NY                 20
# 10   9   54                  1  Female    IA                 15
# 11  10   60                  3  Female    OK                 20
# 12  10   38                  1    Male    NJ                  4
# 13  11   58                  2  Female    NM                 14
# 14  11   60                  1  Female    NY                 12
# 15  12   58                  1  Female    FL                  4
# 16  12   58                  3    Male    OH                  3
# 17  13   58                  1    Male    KY                 16
# 18  14   56                  1    Male    NC                 11
# 19  15   58                  1    Male    CA                 10
# 20  16   60                  1  Female    NH                 13
# 21  17   50                  4  Female    IL                 17
# 22  18   55                  1  Female    MI                 18
# 23  18   24                  1    Male    CA                 16
# 24  19   44                  4    Male    HI                  4
# 25  19   30                  1  Female    UT                 12
# 26  20   59                  1    Male    MT                 20
# 27  20   47                  1  Female    OK                  7
# 28  21   53                  3  Female    WA                 20
# 29  21   41                  1    Male    PA                 16
# 30  22   56                  2  Female    CA                 18
# 31  22   56                  1  Female    CA                 16
# 32  23   49                  1  Female    TN                  9
# 33  24   47                  2  Female    MO                  2
# 34  24   52                  1  Female    GA                  1
# 35  25   54                  1    Male    CA                 18
# 36  26   41                  1    Male    AL                  2
# 37  26   51                  1  Female    CO                 12
# 38  27   60                  3    Male    NV                 13
# 39  28   28                  1  Female    UT                 16
# 40  28   60                  1    Male    MT                 14
# 41  29   40                  1    Male    OH                  2
# 42  29   39                  1    Male    MN                 16
# 43  30   55                  1    Male    TX                 15
# 44  30   28                  3  Female    FL                 19
# 45  31   56                  3    Male    MO                  3
# 46  32   58                  3  Female    IL                 16
# 47  33   49                  1  Female    CT                 15
# 48  34   38                  1    Male    TX                 14
# 49  34   57                  1  Female    NY                 13
# 50  35   59                  3    Male    MA                 99
# 51  35   60                  3  Female    NY                 12
# 52  36   59                  3    Male    FL                 14
# 53  36   59                  1  Female    MN                 10
# 54  37   28                  1  Female    TX                 16
# 55  38   51                  1    Male    CO                 16
# 56  38   55                  3    Male    MI                 19
# 57  39   35                  1  Female    UT                  2
# 58  40   28                  1  Female    MI                 20
# 59  40   59                  1    Male    CA                  9
#
#     wake_up_weekdays  bed_time_wrong  wake_up_wrong  time_awake_wrong  ...  \
# 0                 17          1000.0         2050.0            1050.0  ...
# 1                  7           900.0         1800.0             900.0  ...
# 2                  9          1000.0         1850.0             850.0  ...
# 3                 10          1025.0         1875.0             850.0  ...
# 4                  8          1100.0         1825.0             725.0  ...
# 5                 14          1100.0         1975.0             875.0  ...
# 6                  9          1100.0         1850.0             750.0  ...
# 7                 15           900.0         2000.0            1100.0  ...
# 8                 12           950.0         1925.0             975.0  ...
# 9                  7          1150.0         1800.0             650.0  ...
# 10                10          1025.0         1875.0             850.0  ...
# 11                24          1150.0         2300.0            1150.0  ...
# 12                13          1400.0         1950.0             550.0  ...
# 13                15          1000.0         2000.0            1000.0  ...
# 14                 4           950.0         1725.0             775.0  ...
# 15                 7          1400.0         1800.0             400.0  ...
# 16                17          1300.0         2050.0             750.0  ...
# 17                 8          1050.0         1825.0             775.0  ...
# 18                 5           925.0         1750.0             825.0  ...
# 19                 7           900.0         1800.0             900.0  ...
# 20                 9           975.0         1850.0             875.0  ...
# 21                 6          1075.0         1775.0             700.0  ...
# 22                 9          1100.0         1850.0             750.0  ...
# 23                 2          1050.0         1201.7             151.7  ...
# 24                23          1400.0         2200.0             800.0  ...
# 25                11           950.0         1900.0             950.0  ...
# 26                17          1150.0         2050.0             900.0  ...
# 27                26             0.0          600.0             600.0  ...
# 28                15          1150.0         2000.0             850.0  ...
# 29                 5          1050.0         1750.0             700.0  ...
# 30                 7          1100.0         1800.0             700.0  ...
# 31                12          1050.0         1925.0             875.0  ...
# 32                 7           800.0         1800.0            1000.0  ...
# 33                 5          1201.7         1750.0             548.3  ...
# 34                 7          1200.0         1800.0             600.0  ...
# 35                 9          1100.0         1850.0             750.0  ...
# 36                 6          1201.7         1775.0             573.3  ...
# 37                 2           950.0         1201.7             251.7  ...
# 38                 8           975.0         1825.0             850.0  ...
# 39                13          1050.0         1950.0             900.0  ...
# 40                 9          1000.0         1850.0             850.0  ...
# 41                13          1201.7         1950.0             748.3  ...
# 42                 9          1050.0         1850.0             800.0  ...
# 43                 7          1025.0         1800.0             775.0  ...
# 44                 8          1125.0         1825.0             700.0  ...
# 45                19          1300.0         2100.0             800.0  ...
# 46                23          1050.0         2200.0            1150.0  ...
# 47                 7          1025.0         1800.0             775.0  ...
# 48                 4          1000.0         1725.0             725.0  ...
# 49                 8           975.0         1825.0             850.0  ...
# 50                 7          9999.0         1800.0            9999.0  ...
# 51                23           950.0         2200.0            1250.0  ...
# 52                 9          1000.0         1850.0             850.0  ...
# 53                 2           900.0         1201.7             301.7  ...
# 54                11          1050.0         1900.0             850.0  ...
# 55                13          1050.0         1950.0             900.0  ...
# 56                13          1125.0         1950.0             825.0  ...
# 57                17          1201.7         2050.0             848.3  ...
# 58                11          1150.0         1900.0             750.0  ...
# 59                 5           800.0         1750.0             950.0  ...
#
#     hispanic                    race  bed_time_weekend_wrong  \
# 0          2         White/Caucasian                  1000.0
# 1          2         White/Caucasian                  2100.0
# 2          2         White/Caucasian                  1000.0
# 3          2         White/Caucasian                  1100.0
# 4          2         White/Caucasian                  1100.0
# 5          2         White/Caucasian                  1150.0
# 6          2         White/Caucasian                  1200.0
# 7          2         White/Caucasian                   900.0
# 8          2         White/Caucasian                   950.0
# 9          2                 Refused                  1201.7
# 10         2         White/Caucasian                  1100.0
# 11         2         White/Caucasian                  1125.0
# 12         1         White/Caucasian                  1400.0
# 13         2         White/Caucasian                  1000.0
# 14         1         White/Caucasian                  1000.0
# 15         1                   Asian                  1400.0
# 16         2         White/Caucasian                  1300.0
# 17         2         White/Caucasian                  1100.0
# 18         2         White/Caucasian                  1025.0
# 19         2         White/Caucasian                  1000.0
# 20         2         White/Caucasian                  1000.0
# 21         2         White/Caucasian                  1075.0
# 22         2         White/Caucasian                  1150.0
# 23         2         White/Caucasian                  1050.0
# 24         2                   Asian                  1400.0
# 25         1              Don't Know                  1100.0
# 26         2         White/Caucasian                  1150.0
# 27         2         White/Caucasian                   900.0
# 28         2         White/Caucasian                  1150.0
# 29         2         White/Caucasian                  1050.0
# 30         2         White/Caucasian                  1150.0
# 31         2         White/Caucasian                  1150.0
# 32         2         White/Caucasian                  1000.0
# 33         2         White/Caucasian                  1300.0
# 34         2         White/Caucasian                  1200.0
# 35         2                   Asian                  1150.0
# 36         2         White/Caucasian                  1201.7
# 37         2         White/Caucasian                  1100.0
# 38         2         White/Caucasian                   975.0
# 39         2         White/Caucasian                   700.0
# 40         2         White/Caucasian                  1000.0
# 41         2         White/Caucasian                  1300.0
# 42         2         White/Caucasian                  1100.0
# 43         1         White/Caucasian                  1150.0
# 44         2         White/Caucasian                  1200.0
# 45         2         White/Caucasian                  1300.0
# 46         2  Black/African-American                  1075.0
# 47         2         White/Caucasian                  1150.0
# 48         2         White/Caucasian                  1000.0
# 49         2         White/Caucasian                  1025.0
# 50         2         White/Caucasian                  9999.0
# 51         2         White/Caucasian                   975.0
# 52         2         White/Caucasian                  1200.0
# 53         2         White/Caucasian                  1000.0
# 54         2         White/Caucasian                  1175.0
# 55         2         White/Caucasian                  1201.7
# 56         2         White/Caucasian                  1175.0
# 57         2         White/Caucasian                  1300.0
# 58         2         White/Caucasian                  1200.0
# 59         2         White/Caucasian                   950.0
#
#     wake_up_weekend_wrong  total_height_inch    bmi    regions  age_bin  \
# 0                  2050.0               73.0  20.98       West    30-40
# 1                  2100.0               69.0  34.70      South    50-60
# 2                  1900.0               74.0  25.03       West    50-60
# 3                  2000.0               71.0    NaN      South      NaN
# 4                  2050.0               69.0  22.89  Northeast    50-60
# 5                  2075.0               66.0  23.24  Northeast    30-40
# 6                  2100.0               60.0  35.54      South    30-40
# 7                  2000.0               67.0  19.11  Northeast    40-50
# 8                  2000.0               69.0  19.93       West    30-40
# 9                  2175.0               70.0  24.39  Northeast    30-40
# 10                 1950.0               64.0  29.18    Midwest    50-60
# 11                 1850.0               64.0  23.51      South    50-60
# 12                 2150.0               75.0  30.24  Northeast    30-40
# 13                 2000.0               62.0  25.60       West    50-60
# 14                 1800.0               67.0  24.59  Northeast    50-60
# 15                 2200.0               56.0  30.26      South    50-60
# 16                 2050.0               69.0  24.36    Midwest    50-60
# 17                 2000.0               74.0  30.81      South    50-60
# 18                 1850.0               66.0  29.86      South    50-60
# 19                 1875.0               66.0  28.24       West    50-60
# 20                 2050.0               68.0  24.33  Northeast    50-60
# 21                 1775.0               67.0  24.27    Midwest    40-50
# 22                 1925.0               68.0  27.37    Midwest    50-60
# 23                 2100.0               67.0  25.06       West    20-30
# 24                 2200.0               65.0  25.79       West    40-50
# 25                 1900.0               68.0  27.37       West    20-30
# 26                 2075.0               71.0  25.80       West    50-60
# 27                 2000.0               64.0  40.16      South    40-50
# 28                 2050.0               68.0  33.45       West    50-60
# 29                 1900.0               70.0  26.40  Northeast    40-50
# 30                 1950.0               68.0  21.28       West    50-60
# 31                 2075.0               63.0  28.69       West    50-60
# 32                 2000.0               68.0  23.57      South    40-50
# 33                 2075.0               67.0  40.72    Midwest    40-50
# 34                 1900.0               64.0  24.89      South    50-60
# 35                 1975.0               67.0  22.24       West    50-60
# 36                 1925.0               66.0  33.08      South    40-50
# 37                 1900.0               62.0  22.86       West    50-60
# 38                 1825.0               68.0  30.41       West    50-60
# 39                 2000.0               66.0  19.04       West    20-30
# 40                 1900.0               72.0  27.80       West    50-60
# 41                 2050.0               68.0  27.37    Midwest    30-40
# 42                 2100.0               69.0  28.79    Midwest    30-40
# 43                 2050.0               70.0  32.28      South    50-60
# 44                 2000.0               62.0  21.95      South    20-30
# 45                 2100.0               68.0  27.37    Midwest    50-60
# 46                 2200.0               64.0  25.74    Midwest    50-60
# 47                 2150.0               67.0  25.06  Northeast    40-50
# 48                 1900.0               74.0    NaN      South      NaN
# 49                 1825.0               60.0  17.18  Northeast    50-60
# 50                 1800.0               68.0  26.61  Northeast    50-60
# 51                 2200.0               63.0  20.72  Northeast    50-60
# 52                 2000.0               72.0  27.12      South    50-60
# 53                 1750.0               66.0  20.98    Midwest    50-60
# 54                 2200.0               65.0  23.63      South    20-30
# 55                 1950.0               68.0  26.61       West    50-60
# 56                 2000.0               80.0  29.11    Midwest    50-60
# 57                 2175.0               68.0  23.57       West    30-40
# 58                 2000.0               68.0  25.09    Midwest    20-30
# 59                 1900.0               72.0  27.80       West    50-60
#
#     bmi_bin  cluster_group
# 0     20-25            2.0
# 1     30-35            4.0
# 2     25-30            6.0
# 3       NaN            NaN
# 4     20-25           10.0
# 5     20-25            1.0
# 6     35-40           16.0
# 7     15-20            3.0
# 8     15-20           16.0
# 9     20-25           14.0
# 10    25-30            4.0
# 11    20-25           10.0
# 12    30-35            3.0
# 13    25-30            4.0
# 14    20-25            4.0
# 15    30-35            4.0
# 16    20-25           10.0
# 17    30-35            3.0
# 18    25-30           13.0
# 19    25-30           18.0
# 20    20-25           10.0
# 21    20-25           17.0
# 22    25-30            6.0
# 23    25-30           19.0
# 24    25-30            7.0
# 25    25-30            1.0
# 26    25-30           13.0
# 27    40-45            8.0
# 28    30-35            4.0
# 29    25-30            7.0
# 30    20-25            6.0
# 31    25-30            4.0
# 32    20-25           11.0
# 33    40-45            8.0
# 34    20-25            4.0
# 35    20-25            2.0
# 36    30-35            3.0
# 37    20-25           10.0
# 38    30-35            4.0
# 39    15-20           16.0
# 40    25-30           19.0
# 41    25-30            9.0
# 42    25-30            1.0
# 43    30-35            3.0
# 44    20-25            4.0
# 45    25-30            6.0
# 46    25-30            6.0
# 47    25-30            1.0
# 48      NaN            NaN
# 49    15-20            4.0
# 50    25-30            6.0
# 51    20-25            4.0
# 52    25-30           13.0
# 53    20-25           10.0
# 54    20-25            4.0
# 55    25-30           13.0
# 56    25-30           13.0
# 57    20-25           17.0
# 58    25-30           15.0
# 59    25-30           13.0
#
# [60 rows x 143 columns]

# %% [markdown]
# ## Initial Cluster Popularity Preview
#  To gain insight into which clusters matter the most for each attribute, the initial perspective will be given for each cluster for each attribute.

# %%
gender_analysis = (cluster_df
                   .sort_values(['cluster_group'])
                   .groupby('cluster_group')['gender']
                   .describe()
                   .sort_values(['freq'], ascending=False))
# .drop_duplicates('top', keep='first'))
gender_analysis.iloc[:, 2:].head(9)
# Out:
#                   top freq
# cluster_group
# 3.0              Male  103
# 2.0              Male   85
# 1.0            Female   80
# 4.0            Female   66
# 11.0           Female   53
# 7.0              Male   48
# 14.0             Male   47
# 0.0            Female   43
# 18.0             Male   43

# %%
marital_status_analysis = (cluster_df
                           .sort_values(['cluster_group'])
                           .groupby('cluster_group')['marital_status']
                           .describe()
                           .sort_values(['freq'], ascending=False))
# .drop_duplicates('top', keep='first'))
marital_status_analysis.iloc[:, 2:].head(6)
# Out:
#                                 top freq
# cluster_group
# 3.0            married_or_partnered   89
# 1.0            married_or_partnered   77
# 2.0            married_or_partnered   77
# 14.0                         single   62
# 4.0            married_or_partnered   49
# 6.0            married_or_partnered   48

# %%
age_analysis = (cluster_df
                .sort_values(['cluster_group'])
                .groupby('cluster_group')['age_bin']
                .describe()
                .sort_values(['freq'], ascending=False))
age_analysis.iloc[:, 2:].head(6)
# Out:
#                  top freq
# cluster_group
# 1.0            30-40   79
# 3.0            40-50   63
# 2.0            30-40   61
# 6.0            50-60   59
# 14.0           20-30   57
# 4.0            50-60   47

# %%
bmi_analysis = (cluster_df
                .sort_values(['cluster_group'])
                .groupby('cluster_group')['bmi_bin']
                .describe()
                .sort_values(['freq'], ascending=False))
bmi_analysis.iloc[:, 2:].head(6)
# Out:
#                  top freq
# cluster_group
# 3.0            30-35   87
# 2.0            20-25   76
# 1.0            25-30   56
# 14.0           20-25   54
# 11.0           20-25   53
# 7.0            25-30   48

# %%
health_rating_analysis = (cluster_df
                          .sort_values(['cluster_group'])
                          .groupby('cluster_group')['health_rating']
                          .describe()
                          .sort_values(['freq'], ascending=False))

health_rating_analysis.iloc[:,2:].head(6)
# Out:
#                      top freq
# cluster_group
# 1.0                 Good   99
# 3.0                 Good   84
# 14.0                Good   56
# 2.0            Excellent   55
# 4.0                 Good   50
# 6.0                 Good   50

# %%
sleep_rating_analysis = (cluster_df
                         .sort_values(['cluster_group'])
                         .groupby('cluster_group')['sleep_rating']
                         .describe()
                         .sort_values(['freq'], ascending=False))
# .drop_duplicates('top', keep='first'))
sleep_rating_analysis.iloc[:,2:].head(6)
# Out:
#                        top freq
# cluster_group
# 3.0            Fairly Good   88
# 1.0            Fairly Good   80
# 2.0            Fairly Good   69
# 6.0            Fairly Good   57
# 4.0             Fairly Bad   56
# 14.0           Fairly Good   53

# %% [markdown]
# To streamline to decision making process, a function is made with the design to count the number of times a top cluster is associated with a particular attribute.

# %%
x = np.arange(0,20,1)
sum_df = pd.DataFrame(x, columns=['cluster_group'])

# %%
sum_df['mentioned'] = [0]*20

# %%
index_list = [bmi_analysis.index, age_analysis.index,
              health_rating_analysis.index, sleep_rating_analysis.index,
              marital_status_analysis.index, gender_analysis.index]
def count_cluster_relative_size(sum_df, index_list):
    for mention in index_list:
        i=0

        for m in mention:
            i+=1
            if i>5:
                break
            else:
                sum_df['mentioned'][m] += 1
    return sum_df

# %%
sum_df = count_cluster_relative_size(sum_df, index_list)

# %%
sum_df = sum_df.sort_values(['mentioned'], ascending=False).head(6)

# %%
sum_df.index
# Out:
# Int64Index([2, 3, 1, 4, 14, 6], dtype='int64')

# %% [markdown]
# ##  Remove Irrelevant Clusters
#  With a 'mentions' column now added, the bottom 16 clusters can be removed, just leaving the most pertinent clusters for our analysis.

# %%
def clean_unneeded_clusters(x, index):
    if x == index[0]:
        return x
    elif x == index[1]:
        return x
    elif x == index[2]:
        return x
    elif x == index[3]:
        return x
    elif x == index[4]:
        return x
    elif x == index[5]:
        return x
    else:
        return np.nan

# %%
cluster_df['cluster_group'] = cluster_df['cluster_group'].apply(lambda x: clean_unneeded_clusters(x, sum_df.index))

# %%
cluster_df_copy = cluster_df.copy()

# %%
cluster_df.dropna(subset=['cluster_group'], inplace=True)

# %%
cluster_df
# Out:
#       id  age  employment_status  gender state  bed_time_weekdays  \
# 0      1   39                  3    Male    CO                 14
# 1      2   57                  1  Female    AL                 10
# 2      3   51                  1    Male    NV                 14
# 5      5   39                  1  Female    MA                 18
# 7      7   44                  3    Male    NY                 10
# ..   ...  ...                ...     ...   ...                ...
# 988  944   38                  1  Female    NY                 14
# 992  949   36                  1  Female    NY                 18
# 993  951   34                  2  Female    NJ                 16
# 996  959   26                  1    Male    NY                  2
# 998  964   53                  1    Male    NE                 16
#
#      wake_up_weekdays  bed_time_wrong  wake_up_wrong  time_awake_wrong  ...  \
# 0                  17          1000.0         2050.0            1050.0  ...
# 1                   7           900.0         1800.0             900.0  ...
# 2                   9          1000.0         1850.0             850.0  ...
# 5                  14          1100.0         1975.0             875.0  ...
# 7                  15           900.0         2000.0            1100.0  ...
# ..                ...             ...            ...               ...  ...
# 988                 7          1000.0         1800.0             800.0  ...
# 992                11          1100.0         1900.0             800.0  ...
# 993                11          1050.0         1900.0             850.0  ...
# 996                13          1201.7         1950.0             748.3  ...
# 998                 7          1050.0         1800.0             750.0  ...
#
#      hispanic             race  bed_time_weekend_wrong  wake_up_weekend_wrong  \
# 0           2  White/Caucasian                  1000.0                 2050.0
# 1           2  White/Caucasian                  2100.0                 2100.0
# 2           2  White/Caucasian                  1000.0                 1900.0
# 5           2  White/Caucasian                  1150.0                 2075.0
# 7           2  White/Caucasian                   900.0                 2000.0
# ..        ...              ...                     ...                    ...
# 988         2  White/Caucasian                  1100.0                 2000.0
# 992         2  White/Caucasian                  1100.0                 2000.0
# 993         2  White/Caucasian                  1100.0                 1900.0
# 996         2  White/Caucasian                  1400.0                 2200.0
# 998         2  White/Caucasian                  1050.0                 1900.0
#
#      total_height_inch    bmi    regions  age_bin  bmi_bin  cluster_group
# 0                 73.0  20.98       West    30-40    20-25            2.0
# 1                 69.0  34.70      South    50-60    30-35            4.0
# 2                 74.0  25.03       West    50-60    25-30            6.0
# 5                 66.0  23.24  Northeast    30-40    20-25            1.0
# 7                 67.0  19.11  Northeast    40-50    15-20            3.0
# ..                 ...    ...        ...      ...      ...            ...
# 988               64.0  32.61  Northeast    30-40    30-35            4.0
# 992               63.0  25.33  Northeast    30-40    25-30            1.0
# 993               61.0  21.73  Northeast    30-40    20-25            2.0
# 996               63.0  23.03  Northeast    20-30    20-25            2.0
# 998               70.0  30.13    Midwest    50-60    30-35            3.0
#
# [518 rows x 143 columns]

# %%
cluster_df.groupby('cluster_group')['cluster_group'].count()
# Out:
# cluster_group
# 1.0     103
# 2.0      96
# 3.0     117
# 4.0      72
# 6.0      59
# 14.0     71
# Name: cluster_group, dtype: int64

# %%
health_subset = health_rating_analysis.T[sum_df.index]
sleep_subset = sleep_rating_analysis.T[sum_df.index]
bmi_subset = bmi_analysis.T[sum_df.index]
age_subset = age_analysis.T[sum_df.index]
marital_subset = marital_status_analysis.T[sum_df.index]
gender_subset = gender_analysis.T[sum_df.index]

# %%
cluster_population_count = cluster_df.groupby('cluster_group')['cluster_group'].count()
cluster_population_count.index.name = None
cluster_population_count.rename('Cluster Count', inplace=True)
cluster_population_count = cluster_population_count.reindex(sum_df.index)
cluster_population_count
# Out:
# 2      96
# 3     117
# 1     103
# 4      72
# 14     71
# 6      59
# Name: Cluster Count, dtype: int64

# %%
sum_df['health'] = health_subset.T['top']
sum_df['sleep'] = sleep_subset.T['top']
sum_df['bmi'] = bmi_subset.T['top']
sum_df['age'] = age_subset.T['top']
sum_df['marital_status'] = marital_subset.T['top']
sum_df['gender'] = gender_subset.T['top']
sum_df['cluster_count'] = cluster_population_count

# %%
sum_df
# Out:
#     cluster_group  mentioned     health        sleep    bmi    age  \
# 2               2          6  Excellent  Fairly Good  20-25  30-40
# 3               3          6       Good  Fairly Good  30-35  40-50
# 1               1          6       Good  Fairly Good  25-30  30-40
# 4               4          4       Good   Fairly Bad  30-35  50-60
# 14             14          4       Good  Fairly Good  20-25  20-30
# 6               6          2       Good  Fairly Good  25-30  50-60
#
#           marital_status  gender  cluster_count
# 2   married_or_partnered    Male             96
# 3   married_or_partnered    Male            117
# 1   married_or_partnered  Female            103
# 4   married_or_partnered  Female             72
# 14                single    Male             71
# 6   married_or_partnered  Female             59

# %%
sum_df.iloc[:,2:].sort_index(ascending=False).head(7)
# Out:
#        health        sleep    bmi    age        marital_status  gender  \
# 14       Good  Fairly Good  20-25  20-30                single    Male
# 6        Good  Fairly Good  25-30  50-60  married_or_partnered  Female
# 4        Good   Fairly Bad  30-35  50-60  married_or_partnered  Female
# 3        Good  Fairly Good  30-35  40-50  married_or_partnered    Male
# 2   Excellent  Fairly Good  20-25  30-40  married_or_partnered    Male
# 1        Good  Fairly Good  25-30  30-40  married_or_partnered  Female
#
#     cluster_count
# 14             71
# 6              59
# 4              72
# 3             117
# 2              96
# 1             103

# %%
sum_df.iloc[:,2:].sort_index(ascending=False).head(7).to_latex('../data_file/latex_dataframes/cluster_descriptions.tex', index = True)
sum_df.iloc[:, 2:].to_pickle('../data_file/cleaned_data_pickle/cluster_descriptions.pickle')

# %%
cluster_df_copy.to_csv(r'../data_file/cleaned_data_csv/cluster_oriented_2013_poll.csv', index = False)
cluster_df_copy.to_pickle('../data_file/cleaned_data_pickle/cluster_oriented_2013_poll.pickle')
